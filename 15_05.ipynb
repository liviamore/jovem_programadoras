# %%
# classificar um  triangulo
lado1 = float(input("digite a medida do lado 1:"))
lado2 = float(input("digite a medida do lado 2:"))
lado3 = float(input("digite a medida do lado 3:"))
if lado1 == lado2 and lado2 == lado3 and lado1 == lado3:
  print("e um triangulo aquilatero.")
elif lado1 != lado2 and lado2 != lado3 and lado1 != lado3:
  print("e um triangulo escaleno.")
else:
    print("e um triangulo isosceles.")
# Out:
# digite a medida do lado 1:2
# digite a medida do lado 2:2
# digite a medida do lado 3:2
# e um triangulo aquilatero.

# %%
lado1 = float(input("digite a medida do lado 1:"))
lado2 = float(input("digite a medida do lado 2:"))
lado3 = float(input("digite a medida do lado 3:"))
if lado1 == lado2 and lado2 == lado3 and lado1 == lado3:
  print("e um triangulo aquilatero.")
elif lado1 != lado2 and lado2 != lado3 and lado1 != lado3:
  print("e um triangulo escaleno.")
else:
    print("e um triangulo isosceles.")
# Out:
# digite a medida do lado 1:585
# digite a medida do lado 2:77
# digite a medida do lado 3:99
# e um triangulo escaleno.

# %%
lado1 = float(input("digite a medida do lado 1:"))
lado2 = float(input("digite a medida do lado 2:"))
lado3 = float(input("digite a medida do lado 3:"))
if lado1 == lado2 and lado2 == lado3 and lado1 == lado3:
  print("e um triangulo aquilatero.")
elif lado1 != lado2 and lado2 != lado3 and lado1 != lado3:
  print("e um triangulo escaleno.")
else:
    print("e um triangulo isosceles.")
# Out:
# digite a medida do lado 1:55
# digite a medida do lado 2:55
# digite a medida do lado 3:63
# e um triangulo isosceles.

# %%
# desenhar um retangulo
# le o tamanho do retangulo:
largura = int(input("digite a largura:"))
altura = int(input("digite a altura:"))
# imprime a borda superior:
print('#' + ' ' * (largura-2) + '#')
# imprime borda laterais:
for _ in range(altura-2):
  print('#' + ' ' * (largura-2) + '#')
# imprime borda inferior:
print('#' * largura)
# Out:
# digite a largura:10
# digite a altura:10
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# #        #
# ##########

# %%
# desenhar um retangulo
# le o tamanho do retangulo:
largura = int(input("digite a largura:"))
altura = int(input("digite a altura:"))
# imprime a borda superior:
print('#' + ' ' * (ladob-2) + '#')
# imprime borda laterais:
for _ in range(ladoa-2):
  print('#' + ' ' * (ladob-2) + '#')
# imprime borda inferior:
print('#' * ladoa)
# Out:
# digite a largura:51
# digite a altura:51
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-4eaec609080b> in <cell line: 6>()
#       4 altura = int(input("digite a altura:"))
#       5 # imprime a borda superior:
# ----> 6 print('#' + ' ' * (ladob-2) + '#')
#       7 # imprime borda laterais:
#       8 for _ in range(ladoa-2):
#
# NameError: name 'ladob' is not defined

# %%
# grafico linear
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 9, 10,)
y = 2 * x
plt.plot(x, y, "b-")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 4 * np.pi, 1000)
y = np.sin(x)
plt.plot(x, y, "r--")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 20, 21)
for line_width in [0,5, 1, 2, 4, 8]:
  y = line_width * x
  plt.plot(x, y, 'k', linewidth=line_width)
  
plt.title("line width")
plt.grid(True)
plt.show()
